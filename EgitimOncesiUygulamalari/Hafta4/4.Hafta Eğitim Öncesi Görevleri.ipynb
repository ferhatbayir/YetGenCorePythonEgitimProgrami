# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
telefon_rehberi = {"Mehmet": "0999 999 99 99", 
                   "Berkcan": "0888 888 88 88", 
                   "Begüm": "0777 777 77 77", 
                   "Ferhat": "0666 666 66 66"
                   }

name = str(input("Lütfen numarası öğrenmek istediğiniz kişinin adını girin: "))

if name in telefon_rehberi:
    print(name , "adlı kişinin numarası şu şekildedir: " , telefon_rehberi[name])
else:
    print(f"Maaalesef, {name} adlı kişi telefon rehberinizde  kayıtlı değil.")
# Out:
# Ferhat adlı kişinin numarası şu şekildedir:  0666 666 66 66

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
calisanlar = {
    "Ahmet Yılmaz": ["İstanbul", 30, "Mühendis"],
    "Mehmet Yağız": ["Adana", 40, "Direktör"],
    "Zeynep Özcan": ["Ankara", 25, "Pazarlama uzmanı"],
    "Sibel Can": ["İzmir", 28, "Satış temsilcisi"]
}

name = input("Lütfen bilgilerini görüntülemek istediğiniz çalışanının adını giriniz: ")

if name in calisanlar:
    info = calisanlar[name]
    print(name + " = Memleket: " + info[0] + " yaş: " + str(info[1]) + " Görev: " + info[2])
else:
    print("Bu isimde bir çalışan bulunamadı.")
# Out:
# Bu isimde bir çalışan bulunamadı.

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
ogrenciler = {
    "Mehmet": [72, 66, 48],
    "Ahmet": [55, 76, 63],
    "Zeynep": [82, 74, 89]
    }

name = input("Lütfen notlarını görüntülemek istediğiniz öğrencinin adını girin: ")

if name in ogrenciler:
   notlar = ogrenciler[name]
else:
   print("Hata: {} adında öğrenci bulunamadı.".format(name))
   exit()

print("{} isimli öğrencinin".format(name))
for i in range(len(notlar)):
   print("{0}.Sınav notu:{1}".format(i+1, notlar[i]))
average = sum(notlar) / len(notlar)
print("Not Ortalaması: {:.1f}".format(average))
# Out:
# Mehmet isimli öğrencinin
# 1.Sınav notu:72
# 2.Sınav notu:66
# 3.Sınav notu:48
# Not Ortalaması: 62.0

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.

car_list = ["Bmw", "Mercedes", "Opel", "Mazda"]
print("1:\t",car_list)


# 2-  Liste Kaç elemanlıdır ?

print("2:\t",len(car_list))
      
# 3-  Listenin ilk ve son elemanı nedir ?

print("3:,\t", car_list[0], ",", car_list[-1])

# 4-  Mazda değerini Toyota ile değiştirin.

car_list[car_list.index("Mazda")] = "Toyota"
print("4:,\t", car_list)

# 5-  Listenin -2 indeksindeki değer nedir ?

print("5:\t", car_list[-2])

# 6-  Listenin ilk 3 elemanını alın.

print("6:\t", car_list[:3])

# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.

car_list[-2:] = ["Toyota", "Renault"]
print("7:\t", car_list)

# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.

car_list.extend(["Audi", "Nissan"])
print("8:\t", car_list)

# 9- Listenin son elemanını silin.

car_list.pop()
print("9:\t", car_list)

# 10- Liste elemanlarını tersten yazdırınız.

car_list.reverse()
print("10:\t", car_list)

# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 

students = [
    {"name": "Yiğit Bilgi", "year": 2010, "grades": (70,60,70)},
    {"name": "Sena Turan", "year": 1999, "grades": (80,80,70)},
    {"name": "Ahmet Turan", "year": 1998, "grades": (80,70,90)}
]

print("11:\t",students)

# 12- Liste elemanlarını ekrana yazdırınız.


 
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

for i in range(len(names)):
    print(names[i], years[i])

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.

names.append("Cenk")
print("13:\t", names)

# 14-  "Sena" değerini listenin başına ekleyiniz.

names.insert(0, "Sena")
print("14:\t", names)

# 15-  "Deniz" ismini listeden siliniz.

names.remove("Deniz")
print("15:\t", names)

# 16-  "Ali" listenin bir elemanı mıdır ?

if "Ali" in names:
    print("16:\t", names)

# 17-  Liste elemanlarını ters çevirin.

names.reverse()
print("17:\t", names)

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.

names.sort()
print("18:\t", names)

# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.

years.sort()
print("19:\t", years)

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.

list = str.split("Chevrolet,Dacia")
print("20:\t", list)

# 21- years dizisinde kaç tane 1998 değeri vardır ?

count = years.count(1998)
print("21:\t", count)

# 22- years dizisinin tüm elemanlarını siliniz.

years.clear()
print("22:\t",years)

# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.

markalar = []

for i in range(3):
    marka = input("Lütfen bir marka ismi giriniz: ")
    markalar.append(marka)

print("23:\t", "Markalar: ", markalar)
# Out:
# 1:	 ['Bmw', 'Mercedes', 'Opel', 'Mazda']
# 2:	 4
# 3:,	 Bmw , Mazda
# 4:,	 ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# 5:	 Opel
# 6:	 ['Bmw', 'Mercedes', 'Opel']
# 7:	 ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# 8:	 ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi', 'Nissan']
# 9:	 ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi']
# 10:	 ['Audi', 'Renault', 'Toyota', 'Mercedes', 'Bmw']
# 11:	 [{'name': 'Yiğit Bilgi', 'year': 2010, 'grades': (70, 60, 70)}, {'name': 'Sena Turan', 'year': 1999, 'grades': (80, 80, 70)}, {'name': 'Ahmet Turan', 'year': 1998, 'grades': (80, 70, 90)}]
# Ali 1998
# Yağmur 2000
# Hakan 1998
# Deniz 1987
# 13:	 ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# 14:	 ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# 15:	 ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# 16:	 ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# 17:	 ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# 18:	 ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
# 19:	 [1987, 1998, 1998, 2000]
# 20:	 ['Chevrolet,Dacia']
# 21:	 2
# 22:	 []
# 23:	 Markalar:  ['Google', 'Apple', 'Amazon']
